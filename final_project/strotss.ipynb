# %%
# !python3 "/content/drive/My Drive/DeepLearning_2020/FinalProject/strotss-master/strotss.py"  "/content/drive/My Drive/DeepLearning_2020/FinalProject/strotss-master/paolo.jpg" "/content/drive/My Drive/DeepLearning_2020/FinalProject/strotss-master/arc_kandinsky.png" --weight 1.0 --output "/content/drive/My Drive/DeepLearning_2020/FinalProject/strotss-master/paolo_starred.png" --device "cuda"
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/checkpoints/vgg16-397923af.pth
# 100% 528M/528M [00:02<00:00, 250MB/s]
# Optimizing at resoluton [64, 64]
# Optimizing at resoluton [128, 128]
# Optimizing at resoluton [256, 256]
# Optimizing at resoluton [512, 512]
# Done in 80.463s
