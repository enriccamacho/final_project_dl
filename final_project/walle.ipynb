# %%
from google.colab import drive
drive.mount('/content/drive')
# !python3 "/content/drive/My Drive/DeepLearning_2020/FinalProject/strotss-master/strotss.py"  "/content/drive/My Drive/DeepLearning_2020/FinalProject/strotss-master/walle.jpg" "/content/drive/My Drive/DeepLearning_2020/FinalProject/strotss-master/style.png" --weight 1.0 --output walle_face.png --device "cuda"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# python3: can't open file '/content/drive/My Drive/DeepLearning_2020/FinalProject/strotss-master/strotss.py': [Errno 2] No such file or directory
